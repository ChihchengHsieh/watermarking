# %%
a  = 5

# %%
import pandas as pd

# %%
df = pd.read_csv(r"C:\Users\chihc\Documents\pc_m\case8\test_result.csv")

# %%
# get the columns has "auroc" in the name
auroc_cols = [col for col in df.columns if "auroc" in col]

# %%
# print value of auroc columns
for col in auroc_cols:
    print(f"{col}: {df[col].values}")
# Out:
# clsa_glaucoma_0_auroc: [0.71850419]
# clsa_glaucoma_2_auroc: [0.72264218]
# clsa_glaucoma_5_auroc: [0.72568202]
# clsa_glaucoma_10_auroc: [nan]
# clsa_glaucoma_0_2_auroc: [0.71126688]
# clsa_glaucoma_2_5_auroc: [0.68075031]
# clsa_glaucoma_5_10_auroc: [nan]
# clsa_ad_0_auroc: [0.55083477]
# clsa_ad_2_auroc: [0.56186223]
# clsa_ad_5_auroc: [0.64644319]
# clsa_ad_10_auroc: [nan]
# clsa_ad_0_2_auroc: [0.49912006]
# clsa_ad_2_5_auroc: [0.64755797]
# clsa_pd_0_auroc: [0.60028839]
# clsa_pd_2_auroc: [0.60797405]
# clsa_pd_5_auroc: [0.61401808]
# clsa_pd_10_auroc: [nan]
# clsa_pd_0_2_auroc: [0.61738873]
# clsa_pd_2_5_auroc: [0.57310581]
# clsa_pd_5_10_auroc: [nan]
# clsa_cvd_0_auroc: [0.7191242]
# clsa_cvd_2_auroc: [0.72453839]
# clsa_cvd_5_auroc: [0.73608547]
# clsa_cvd_10_auroc: [nan]
# clsa_cvd_0_2_auroc: [0.67989707]
# clsa_cvd_2_5_auroc: [0.69334131]
# clsa_cvd_5_10_auroc: [nan]
# clsa_t2d_0_auroc: [0.73071557]
# clsa_t2d_2_auroc: [0.73506814]
# clsa_t2d_5_auroc: [0.74641889]
# ...
