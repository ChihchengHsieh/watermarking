# %%
import matplotlib.pyplot as plt

fig, ax = plt.subplots(figsize=(9, 3))
ax.set_xlim(0, 9)
ax.set_ylim(0, 3)
ax.axis('off')

# CNN block
ax.text(1, 2.2, "🧠 CNN", fontsize=14, weight='bold', color='royalblue', ha='center')
ax.text(1, 1.3, "Images\n(spatial data)", fontsize=11, ha='center')
ax.arrow(2, 1.5, 1, 0, head_width=0.1, head_length=0.2, color='royalblue')
ax.text(3.2, 1.5, "Feature maps", fontsize=10, color='royalblue')

# MLP block
ax.text(5, 2.2, "🧮 MLP", fontsize=14, weight='bold', color='seagreen', ha='center')
ax.text(5, 1.3, "Tabular data\n(structured)", fontsize=11, ha='center')
ax.arrow(6, 1.5, 1, 0, head_width=0.1, head_length=0.2, color='seagreen')
ax.text(7.2, 1.5, "Prediction", fontsize=10, color='seagreen')

# Upcoming sequential
ax.text(8.3, 2.2, "⏳ Next:\nSequential Data", fontsize=13, ha='center', color='gray')

plt.show()
# Out:
# c:\Users\mike8\anaconda3\envs\ai_env\lib\site-packages\IPython\core\pylabtools.py:170: UserWarning: Glyph 129504 (\N{BRAIN}) missing from font(s) DejaVu Sans.
#   fig.canvas.print_figure(bytes_io, **kw)
# c:\Users\mike8\anaconda3\envs\ai_env\lib\site-packages\IPython\core\pylabtools.py:170: UserWarning: Glyph 129518 (\N{ABACUS}) missing from font(s) DejaVu Sans.
#   fig.canvas.print_figure(bytes_io, **kw)
# c:\Users\mike8\anaconda3\envs\ai_env\lib\site-packages\IPython\core\pylabtools.py:170: UserWarning: Glyph 9203 (\N{HOURGLASS WITH FLOWING SAND}) missing from font(s) DejaVu Sans.
#   fig.canvas.print_figure(bytes_io, **kw)
